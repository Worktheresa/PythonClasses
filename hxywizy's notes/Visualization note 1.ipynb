# %% [markdown]
# # Data Visualization
#
# There are many libraries that can be used for data visualization in python. We will consider the most commonly used ones.
#
# * Pandas
# * Matplotlib
# * Seaborn
#
# Pandas has its own custom visualization. It's built on top of matplotlib and is easy to use. It is basically for quick plots or visualizations and doesn't use many fancy features.
#
# Let's take a look at Pandas custom visualization

# %% [markdown]
# ## Pandas Built-in Data Visualization

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### The Data
#
# We will use a climate data csv file you can read in as dataframe:

# %%
# import the csv file
df1 = pd.read_csv('climate-data-sample.csv')

# %% [markdown]
# We should check out the dataframe before we start any visualization

# %%
# preview the data with head method
df1.head()
# Out:
#    StoreID          City State Date Last Winter Freeze  \
# 0        2       Hayward    WI              2009-06-25
# 1        3        Baxter    MN              2009-05-29
# 2        6  Grand Rapids    MN              2009-06-02
# 3        9     Bottineau    ND              2009-05-31
# 4       10       Bemidji    MN              2009-05-31
#
#   Date First Winter Freeze  Growing Season Length  Jan Avg Tot Prec  \
# 0               2009-08-31                    126             0.532
# 1               2009-09-06                    147             0.352
# 2               2009-09-11                    133             0.370
# 3               2009-09-16                    141             0.256
# 4               2009-09-20                    147             0.176
#
#    Feb Avg Tot Prec  Mar Avg Tot Prec  Apr Avg Tot Prec    ...      \
# 0             0.808             1.636             2.368    ...
# 1             0.464             1.690             1.712    ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 57 columns):
# StoreID                     2127 non-null int64
# City                        2127 non-null object
# State                       2127 non-null object
# Date Last Winter Freeze     2127 non-null object
# Date First Winter Freeze    2127 non-null object
# Growing Season Length       2127 non-null int64
# Jan Avg Tot Prec            2127 non-null float64
# Feb Avg Tot Prec            2127 non-null float64
# Mar Avg Tot Prec            2127 non-null float64
# Apr Avg Tot Prec            2127 non-null float64
# May Avg Tot Prec            2127 non-null float64
# Jun Avg Tot Prec            2127 non-null float64
# Jul Avg Tot Prec            2127 non-null float64
# Aug Avg Tot Prec            2127 non-null float64
# Sep Avg Tot Prec            2127 non-null float64
# Oct Avg Tot Prec            2127 non-null float64
# Nov Avg Tot Prec            2127 non-null float64
# ...

# %% [markdown]
# #### Style Sheets
#
# Matplotlib has [style sheets](http://matplotlib.org/gallery.html#style_sheets) you can use to make your plots look a little nicer. These style sheets include plot_bmh,plot_fivethirtyeight,plot_ggplot and more. They basically create a set of style rules that your plots follow. They make all your plots have the same look and feel more professional.
#
# Here is how to use them.
#
# **Before plt.style.use() your plots look like this:**

# %%
# pandas hist method is used to plot the histogram of a column
df1['Jul Avg Rain'].hist()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# Now the same plot will look different

# %%
# we can plot histograms of two columns at once
df1[['Jul Avg Rain','Jan Avg Rain']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000D1DE255DD8>,
# ...
#       dtype=object)

# %%
plt.style.use('bmh')
df1['Jul Avg Rain'].hist()

# %% [markdown]
# #### Plot Types
#
# There are several plot types built-in to pandas, most of them statistical plots by nature:
#
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie
#
# You can also just call df.plot(kind='hist') or replace that kind argument with any of the key terms shown in the list above (e.g. 'box','barh', etc..)

# %% [markdown]
# #### Area

# %%
# An area chart compares two or more quantities by the area between the line and the axis
df2 = pd.read_excel('school-data-cleaned.xlsx')

# %%
df2 = df2.head(5)
df2
# Out:
#      School    ATT   PATT   PTR     SAL     PPC
# 0     Adair  451.4  90.77  33.8  160.22   66.90
# 1      Crew  440.6  89.32  36.3  146.24   61.08
# 2     Davis  139.4  86.51  22.6  159.79  105.21
# 3     Faith  427.3  91.12  30.0  152.39   75.35
# 4  Formwalt  706.1  89.46  32.5  139.11   59.45

# %%
# ?pd.DataFrame.plot()

# %%
df2.plot.area(alpha=0.5)

# %% [markdown]
# #### Barplots

# %%
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars
# with heights or lengths proportional to the values that they represent
df2.plot.bar()

# %%
# stacked bar represents many quantities on one bar
df2.plot.bar(stacked=True)

# %% [markdown]
# #### Histograms

# %%
# histogram gives the representation of the distribution of numeric data
# by dividing its entire range of values into specific intervals
df1['Jul Avg Rain'].plot.hist(bins=10)

# %% [markdown]
# #### Lineplot

# %%
# A line chart is often used to visualize a trend in data over intervals of time
df1.plot.line(x='StoreID',y=['Jul Avg Temp','Dec Avg Temp'],figsize=(15,5),lw=1)

# %% [markdown]
# #### Scatterplot

# %%
# A scatter plot uses coordinate system to display values for two numeric variables
df1.plot.scatter(x='Jan Avg Snow',y='Jan Avg Temp')

# %% [markdown]
# You can use c to color based off another column value Use cmap to indicate colormap to use. You can increase the dimension of a scatterplot up to four by including size and colour

# %%
df1.plot.scatter(x='Jan Avg Snow',y='Jan Avg Temp', c='Jan Avg Rain', cmap='coolwarm')

# %% [markdown]
# #### Boxplot

# %%
# A box plot (or whisker plot) is used 
# to show the distribution of numerical data and skewness through displaying the data quartiles
df2.plot.box()

# %% [markdown]
# #### Kernel Density Estimation Plot

# %%
# kernel density estimation plot shows estimate of the probability density function of a random variable.
df2['SAL'].plot.kde()

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Matplotlib is the major library of data visualization with Python. It was created by John Hunter.  It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major advantages of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general
#
# Matplotlib allows you to create reproducible figures programmatically. Let's look at how to use it.

# %% [markdown]
# Import the matplotlib.pyplot module under the name plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You'll also need to use this line to see plots in the notebook:

# %%
# %matplotlib inline

# %% [markdown]
# ### Example
#
# We will look at a very simple example using two numpy arrays. You can also use lists, but most likely you'll be passing numpy arrays or pandas columns (which essentially also behave like arrays).
#
# ** The data we want to plot:**

# %%
import numpy as np
x = np.linspace(0, 8, 16)
y = x ** 2

# %%
x
# Out:
# array([0.        , 0.53333333, 1.06666667, 1.6       , 2.13333333,
#        2.66666667, 3.2       , 3.73333333, 4.26666667, 4.8       ,
#        5.33333333, 5.86666667, 6.4       , 6.93333333, 7.46666667,
#        8.        ])

# %%
y
# Out:
# array([ 0.        ,  0.28444444,  1.13777778,  2.56      ,  4.55111111,
#         7.11111111, 10.24      , 13.93777778, 18.20444444, 23.04      ,
#        28.44444444, 34.41777778, 40.96      , 48.07111111, 55.75111111,
#        64.        ])

# %% [markdown]
# We can create a very simple line plot using the following (You can check out the docstrings for functions we are using).

# %%
plt.plot(x, y, 'b') # 'b' is the color blue
plt.xlabel('X ')
plt.ylabel('X squared')
plt.title('My first Plot')
plt.show()

# %% [markdown]
# ### To create multiple plots at once

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'b-*') # More on color options later
plt.subplot(1,2,2)
plt.plot(y, x, 'y--');

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(2,2,1)
plt.plot(x, y, 'r*-') 
plt.subplot(2,2,2)
plt.plot(y, x, 'g-');
plt.subplot(2,2,3)
plt.plot(x, y, 'b--')
plt.subplot(2,2,4)
plt.plot(x, y, 'y')

# %% [markdown]
# ## Matplotlib Object Oriented Method
# Now that we've seen the basics, let's break it all down with a more formal introduction of Matplotlib's Object Oriented API. This means we will instantiate figure objects and then call methods or attributes from that object.

# %%
fig1 =plt.figure()

# %% [markdown]
# ### Introduction to the Object Oriented Method

# %% [markdown]
# The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
# To begin we create a figure instance. Then we can add axes to that figure:

# %%
# Create Figure (empty canvas)
fig = plt.figure()
# Add set of axes to figure
axes = fig.add_axes([0.05, 0.05, 0.95, 0.95]) # left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5,1,'Set Title')

# %% [markdown]
# Code is a little more complicated, but the advantage is that we now have full control of where the plot axes are placed, and we can easily add more than one axis to the figure:

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes1')
axes1.set_ylabel('Y_label_axes1')
axes1.set_title('Axes 1 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'y--')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# ### Saving figures
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.

# %%
fig.savefig("filename.png")

# %% [markdown]
# ### Legends, labels and titles

# %% [markdown]
# **Figure titles**
#
# A title can be added to each axis instance in a figure. To set the title, use the `set_title` method in the axes instance:

# %%
# Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=4)
for ax in axes:
    ax.plot(x, y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

# Display the figure object    
fig
plt.tight_layout()

# %%
ax.set_title("title");

# %% [markdown]
# **Axis labels**
#
# Similarly, with the methods `set_xlabel` and `set_ylabel`, we can set the labels of the X and Y axes:

# %%
ax.set_xlabel("x")
ax.set_ylabel("y");

# %% [markdown]
# ### Legends

# %% [markdown]
# You can use the **label="label text"** keyword argument when plots or other objects are added to the figure, and then using the **legend** method without arguments to add the legend to the figure:

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.plot(x, x**4, label="x**4")
ax.plot(x, x**3.142, label="x**pi")
ax.legend()

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([ 9.,  8.,  6., 12., 11., 14.,  9.,  8.,  9., 14.]),
#  array([ 12. , 110.4, 208.8, 307.2, 405.6, 504. , 602.4, 700.8, 799.2,
#         897.6, 996. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# ### Placement of ticks and custom tick labels

# %% [markdown]
# We can explicitly determine where we want the axis ticks with `set_xticks` and `set_yticks`, which both take a list of values for where on the axis the ticks are to be placed. We can also use the `set_xticklabels` and `set_yticklabels` methods to provide a list of custom text labels for each tick location:

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax.plot(x, x**2, x, x**3, lw=2)

ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'], fontsize=18)

yticks = [0, 50, 100, 150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=20);

# %% [markdown]
# ### Axis number and axis label spacing

# %%
# distance between x and y axis and the numbers on the axes
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5

fig, ax = plt.subplots(1, 1)
      
ax.plot(x, x**2, x, np.exp(x))
ax.set_yticks([0, 200, 400, 600])

ax.set_title("label and axis spacing")

# padding between axis label and axis numbers
ax.xaxis.labelpad = 5
ax.yaxis.labelpad = 5

ax.set_xlabel("x")
ax.set_ylabel("y");

# %% [markdown]
# ### Text annotation

# %%
fig, ax = plt.subplots()

ax.plot(x, x**2, x, x**3)

ax.text(6.0, 50, r"$y=x^2$", fontsize=15, color="blue")
ax.text(4.0, 120, r"$y=x^3$", fontsize=15, color="green");

# %% [markdown]
# ## Further reading

# %% [markdown]
# * http://www.matplotlib.org - The project web page for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcasing various types of plots matplotlib can create.
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
